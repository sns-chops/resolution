# %%
cd /SNS/users/lj7/dv/sns-chops/resolution/ARCS/
# Out:
# /SNS/users/lj7/dv/sns-chops/resolution/ARCS

# %%
#Program to load Vanadium or empty Can powder files and perform a constant-Q cut along the middle Q to look at energy resolution and intensity.
import matplotlib.pyplot as plt
from mantid import plots
from mantid.simpleapi import Load, ConvertToMD, BinMD, ConvertUnits, Rebin
from matplotlib.colors import LogNorm
import numpy as np
import mantid.simpleapi as msa
from mantid import mtd
import scipy

# %%
# %matplotlib notebook

# %%
# ls /SNS/ARCS/IPTS-21387/nexus/

# %%
IPTS=21387
datadir="/SNS/ARCS/IPTS-"+str(IPTS)+"/shared/autoreduce/"

# %% [markdown]
# # gather data
# **This can be skipped the 2nd time running this notebook**

# %%
RunNumber = 108184

# %%
"/SNS/ARCS/IPTS-"+str(IPTS)+"/nexus/ARCS_"+str(RunNumber)+'.nxs.h5'
# Out:
# '/SNS/ARCS/IPTS-21387/nexus/ARCS_108184.nxs.h5'

# %%
# %%time
w=msa.CreateSingleValuedWorkspace()
#LoadNexusLogs(w,"/SNS/ARCS/IPTS-"+str(IPTS)+"/data/ARCS_"+str(RunNumber)+'_event.nxs')
msa.LoadNexusLogs(w,"/SNS/ARCS/IPTS-"+str(IPTS)+"/nexus/ARCS_"+str(RunNumber)+'.nxs.h5')
RunParams=w.getRun()
Energy=RunParams["BL18:Chop:Skf0:EnergyUserReq"].getStatistics().mean
#print Energy
Chopperpos=RunParams["chtrans"].getStatistics().mean
#print Chopperpos
Chopper1=RunParams["Speed1"].getStatistics().mean
Chopper2=RunParams["Speed2"].getStatistics().mean
Chopper3=RunParams["Speed3"].getStatistics().mean
if Chopperpos>400: 
    Chopper=2 
elif Chopperpos<1: 
    Chopper=1 
else: 
    Chopper=0


# generate a nice 2D multi-dimensional workspace
data = msa.LoadNXSPE(datadir+'ARCS_'+str(RunNumber)+'_autoreduced.nxspe')
values=msa.ConvertToMDMinMaxLocal('data',QDimensions='|Q|', dEAnalysisMode='Direct')
minQ,minE=values.MinValues
maxQ,maxE=values.MaxValues

md = msa.ConvertToMD(InputWorkspace=data, QDimensions='|Q|', dEAnalysisMode='Direct')
sqw = msa.BinMD(InputWorkspace=md,
            AlignedDim0='|Q|,'+str(minQ)+','+str(maxQ)+',100',
            AlignedDim1='DeltaE,'+ str(minE) +',' +str(maxE*0.8) +',100')

fig, ax = plt.subplots(subplot_kw={'projection':'mantid'})
c = ax.pcolormesh(sqw, vmin=0., vmax=0.5e-3)
cbar=fig.colorbar(c)
cbar.set_label('Intensity (arb. units)') #add text to colorbar
ax.set_title('Run '+str(RunNumber)+',Ei='+str(Energy)+'meVChoppers=['+str(Chopper1)+','+str(Chopper2)+','+str(Chopper3)+']')
fig.show()


# generate a 1D multi-dimensional workspace


sqw_line= msa.BinMD(
    InputWorkspace=md,
    #AlignedDim0='|Q|,' +str((minQ+maxQ)/3-0.01*maxQ) +','+ str((minQ+maxQ)/3+0.01*maxQ) +',1',
    AlignedDim0='|Q|,%s,%s,1' % ((minQ*2+maxQ)/3 , (minQ+2*maxQ)/3),
    AlignedDim1='DeltaE,'+ str(minE) +',' +str(maxE*0.8) +',100')

sqw_line_Hist=msa.ConvertMDHistoToMatrixWorkspace('sqw_line', Normalization='NumEventsNormalization')

fig, ax = plt.subplots(subplot_kw={'projection':'mantid'})
c = ax.errorbar(sqw_line_Hist,label='Data')
ax.legend()
ax.set_title('Run '+str(RunNumber)+',Ei='+str(Energy)+'meV,|Q|=[' +str((minQ+maxQ)/3-0.01*maxQ) +','+ str((minQ+maxQ)/3+0.01*maxQ) +']' )
fig.show()

xbb, y, Err = sqw_line_Hist.extractX(), sqw_line_Hist.extractY(), sqw_line_Hist.extractE()
xbb.shape = y.shape = Err.shape = -1,
x = (xbb[1:]+xbb[:-1])/2
IE = x,y,Err

RunParams2=data.getRun()
Ei=RunParams2["Ei"].value
Q=(minQ+maxQ)/3
# array=[0,RunNumber, Energy, Ei, Chopper, round(Chopper1), round(Chopper2), round(Chopper3), Height, dHeight, Center, dCenter, Sigma, dSigma, Q]
print("Run=",RunNumber,", Energy=",Energy,"meV, Chopper=",Chopper,"ChopperPosition=",Chopperpos)
# Out:
# <img src="data:image/png;base64,..." width="640">
# /SNS/software/miniconda2/envs/mcvine-unstable/lib/python2.7/site-packages/mantid/plots/helperfunctions.py:154: RuntimeWarning: invalid value encountered in true_divide
#   data /= nev
# <img src="data:image/png;base64,..." width="640">
# ('Run=', 108184, ', Energy=', 100.0, 'meV, Chopper=', 2, 'ChopperPosition=', 432.99999611000004)
# CPU times: user 3.52 s, sys: 1.27 s, total: 4.79 s
# Wall time: 6.04 s

# %%
(minQ*2+maxQ)/3 , (minQ+2*maxQ)/3
# Out:
# (4.9677858750025434, 9.647802372773489)

# %%
path = '/SNS/ARCS/IPTS-%s/nexus/ARCS_%s.nxs.h5' % (IPTS, RunNumber)

# %%
path
# Out:
# '/SNS/ARCS/IPTS-21387/nexus/ARCS_108184.nxs.h5'

# %%
mons = msa.LoadNexusMonitors(path)
print mons.getNumberHistograms()
print Energy

from mcni.utils import conversion as C

v = C.e2v(Energy)
print v

LM1 = 11.831
t = LM1/v*1e6
print t
# Out:
# 2
# 100.0
# 4373.93313724
# 2704.88817016

# %%
mon1 = mons.getSpectrum(0)
tofs = mon1.getTofs()
weights = mon1.getWeights()
intensities, tofbbs = np.histogram(tofs, weights=weights, bins=100, range=(t*.8, t*1.2))
tofcenters = (tofbbs[1:]+tofbbs[:-1])/2

# %%
plt.figure()
plt.plot(tofcenters, intensities)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
Chopper3
# Out:
# 150.001985381922

# %%
Ei
# Out:
# 99.80171647910896

# %% [markdown]
# # Total counts?

# %%
ws = msa.Load('/SNS/ARCS/IPTS-21387/nexus/ARCS_108184.nxs.h5')

# %%
ws = msa.ConvertUnits(InputWorkspace=ws, Target='dSpacing', EMode='Elastic')

# %%
I_d = msa.Rebin(InputWorkspace=ws, Params='0,0.01,11')

# %%
I_d_sum = msa.SumSpectra(InputWorkspace=I_d)

# %%
xbb0 = I_d_sum.readX(0); y0 = I_d_sum.readY(0).copy()
x0 = (xbb0[1:] + xbb0[:-1])/2

# %%
plt.figure()
plt.plot(x0,y0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
y0.sum()
# Out:
# 2810432.0

# %%
print RunParams['start_time'].value
print RunParams['end_time'].value
print RunParams['duration'].value
# Out:
# 2018-06-11T06:43:05.207898666
# 2018-06-11T06:48:14.238296666
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-45-c0a05fb30aff> in <module>()
#       1 print RunParams['start_time'].value
#       2 print RunParams['end_time'].value
# ----> 3 print RunParams['duration'].value
#
# RuntimeError: Unknown property search object duration

# %% [markdown]
# * 5 minutes
# * 5X60X60 pulses = 18000

# %%
2810432.0/18000
# Out:
# 156.13511111111112

# %%
ws.getNumberEvents()
# Out:
# 2832219

# %%
sd = ws.getSampleDetails()
# Out:
# /SNS/software/miniconda2/envs/mcvine-unstable/lib/python2.7/site-packages/ipykernel/__main__.py:1: DeprecationWarning: ``getSampleDetails`` is deprecated, use ``getRun`` instead.
#   if __name__ == '__main__':

# %%
sd.keys()
# Out:
# ['BL18:CS:CrystalAlign:UBMatrix',
#  'BL18:CS:ITEMS',
#  'BL18:CS:ITEMS:CanBarcode',
#  'BL18:CS:ITEMS:CanIndicator',
#  'BL18:CS:ITEMS:CanMaterials',
#  'BL18:CS:ITEMS:CanName',
#  'BL18:CS:ITEMS:Comments',
#  'BL18:CS:ITEMS:Component',
#  'BL18:CS:ITEMS:Container',
#  'BL18:CS:ITEMS:ContainerId',
#  'BL18:CS:ITEMS:Density',
#  'BL18:CS:ITEMS:DensityUnits',
#  'BL18:CS:ITEMS:Description',
#  'BL18:CS:ITEMS:Formula',
#  'BL18:CS:ITEMS:HeightInContainer',
#  'BL18:CS:ITEMS:HeightInContainerUnits',
#  'BL18:CS:ITEMS:InteriorDepth',
#  'BL18:CS:ITEMS:InteriorDepthUnits',
#  'BL18:CS:ITEMS:InteriorDiameter',
#  'BL18:CS:ITEMS:InteriorDiameterUnits',
#  'BL18:CS:ITEMS:InteriorHeight',
#  'BL18:CS:ITEMS:InteriorHeightUnits',
#  'BL18:CS:ITEMS:InteriorWidth',
#  'BL18:CS:ITEMS:InteriorWidthUnits',
#  'BL18:CS:ITEMS:LatticeA',
#  'BL18:CS:ITEMS:LatticeAlpha',
#  'BL18:CS:ITEMS:LatticeB',
#  'BL18:CS:ITEMS:LatticeBeta',
#  'BL18:CS:ITEMS:LatticeC',
#  'BL18:CS:ITEMS:LatticeGamma',
#  'BL18:CS:ITEMS:Mass',
#  'BL18:CS:ITEMS:MassUnits',
#  'BL18:CS:ITEMS:Name',
#  'BL18:CS:ITEMS:Nature',
#  'BL18:CS:ITEMS:OuterDepth',
#  'BL18:CS:ITEMS:OuterDepthUnits',
#  'BL18:CS:ITEMS:OuterDiameter',
#  'BL18:CS:ITEMS:OuterDiameterUnits',
#  'BL18:CS:ITEMS:OuterHeight',
#  'BL18:CS:ITEMS:OuterHeightUnits',
#  'BL18:CS:ITEMS:OuterWidth',
#  'BL18:CS:ITEMS:OuterWidthUnits',
#  'BL18:CS:ITEMS:VolumeCubic',
#  'BL18:CS:ITEMS:VolumeCubicUnits',
#  'BL18:Chop:InUse:ChopperId',
#  'BL18:Chop:InUse:ChopperName',
#  'BL18:Chop:Skf0:EnergyUserReq',
#  'BL18:Chop:Skf0:MotorSpeed',
#  'BL18:Chop:Skf0:PhaseAccuracy',
#  'BL18:Chop:Skf0:PhaseTimeDelaySet',
#  'BL18:Chop:Skf0:SpeedUserReq',
#  'BL18:Chop:Skf0:WavelengthUserReq',
#  'BL18:Chop:Skf1:ChopperId',
#  'BL18:Chop:Skf1:MotorSpeed',
#  'BL18:Chop:Skf1:PhaseAccuracy',
#  'BL18:Chop:Skf1:PhaseLocked',
#  'BL18:Chop:Skf1:PhaseTimeDelaySet',
#  'BL18:Chop:Skf1:SpeedUserReq',
#  'BL18:Chop:Skf2:ChopperId',
#  'BL18:Chop:Skf2:MotorSpeed',
#  'BL18:Chop:Skf2:PhaseAccuracy',
#  'BL18:Chop:Skf2:PhaseLocked',
#  'BL18:Chop:Skf2:PhaseTimeDelaySet',
#  'BL18:Chop:Skf2:SpeedUserReq',
#  'BL18:Det:TH:BL:Ei',
#  'BL18:Det:TH:BL:Frequency',
#  'BL18:Det:TH:BM1:Frame',
#  'BL18:Det:TH:BM1:TrigDelay',
#  'BL18:Det:TH:BM2:Frame',
#  'BL18:Det:TH:BM2:TrigDelay',
#  'BL18:Det:TH:DSPT1:Frame',
#  'BL18:Det:TH:DSPT1:TrigDelay',
#  'BL18:Det:TH:DlyBM1:BasePath',
#  'BL18:Det:TH:DlyBM2:BasePath',
#  'BL18:Det:TH:DlyDet:SegEi',
#  'BL18:Det:TH:DlyDet:SegPath',
#  'BL18:Det:TH:DlySamp:BasePath',
#  'BL18:Mot:Colli:State',
#  'BL18:Mot:Sample:Axis1',
#  'BL18:Mot:Sample:Axis1.DESC',
#  'BL18:Mot:Sample:Axis1.RBV',
#  'BL18:Mot:attenuator1',
#  'BL18:Mot:attenuator1.RBV',
#  'BL18:Mot:attenuator1:Position',
#  'BL18:Mot:attenuator2',
#  'BL18:Mot:attenuator2.RBV',
#  'BL18:Mot:attenuator2:Position',
#  'BL18:Mot:chtrans',
#  'BL18:Mot:chtrans.RBV',
#  'BL18:Mot:chtrans:Position',
#  'BL18:Mot:chtrans:Position(1)',
#  'BL18:Mot:collLift.RBV',
#  'BL18:Mot:collimator:EncoderPos',
#  'BL18:Mot:s1:X:Center',
#  'BL18:Mot:s1:X:Gap.RBV',
#  'BL18:Mot:s1:Y:Center',
#  'BL18:Mot:s1:Y:Gap',
#  'BL18:Mot:s1b',
#  'BL18:Mot:s1b.RBV',
#  'BL18:Mot:s1l',
#  'BL18:Mot:s1l.RBV',
#  'BL18:Mot:s1r',
#  'BL18:Mot:s1r.RBV',
#  'BL18:Mot:s1t',
#  'BL18:Mot:s1t.RBV',
#  'BL18:Mot:s2:X:Center',
#  'BL18:Mot:s2:X:Gap.RBV',
#  'BL18:Mot:s2:Y:Center',
#  'BL18:Mot:s2:Y:Gap',
#  'BL18:Mot:s2b',
#  'BL18:Mot:s2b.RBV',
#  'BL18:Mot:s2l',
#  'BL18:Mot:s2l.RBV',
#  'BL18:Mot:s2r',
#  'BL18:Mot:s2r.RBV',
#  'BL18:Mot:s2t',
#  'BL18:Mot:s2t.RBV',
#  'BL18:SE:Cryo:Pressure:PR1',
#  'BL18:SE:Cryo:Pressure:PR2',
#  'BL18:SE:Cryo:Temp:SAMPLE_TEMP',
#  'BL18:SE:Cryo:Temp:SETP1',
#  'BL18:SE:Cryo:Temp:SETP2',
#  'BL18:SE:Cryo:TempActual',
#  'BL18:SE:Dilfridge:Temperature1',
#  'BL18:SE:Dilfridge:Temperature10',
#  'BL18:SE:Dilfridge:Temperature11',
#  'BL18:SE:Dilfridge:Temperature12',
#  'BL18:SE:Dilfridge:Temperature13',
#  'BL18:SE:Dilfridge:Temperature14',
#  'BL18:SE:Dilfridge:Temperature15',
#  'BL18:SE:Dilfridge:Temperature2',
#  'BL18:SE:Dilfridge:Temperature3',
#  'BL18:SE:Dilfridge:Temperature4',
#  'BL18:SE:Dilfridge:Temperature5',
#  'BL18:SE:Dilfridge:Temperature6',
#  'BL18:SE:Dilfridge:Temperature7',
#  'BL18:SE:Dilfridge:Temperature8',
#  'BL18:SE:Dilfridge:Temperature9',
#  'BL18:SE:GaussMeter:ReadField',
#  'BL18:SE:Lakeshore1:KRDG0',
#  'BL18:SE:Lakeshore1:KRDG1',
#  'BL18:SE:Lakeshore1:KRDG2',
#  'BL18:SE:Lakeshore1:KRDG3',
#  'BL18:SE:Lakeshore2:KRDG0',
#  'BL18:SE:Lakeshore2:KRDG1',
#  'BL18:SE:Lakeshore2:KRDG2',
#  'BL18:SE:Lakeshore2:KRDG3',
#  'BL18:SE:MKS660:Pressure1',
#  'BL18:SE:MKS660:Pressure2',
#  'BL18:SE:MKS660:Pressure3',
#  'BL18:SE:MKS660:Pressure4',
#  'BL18:SE:NANODAC1:CH1:PV',
#  'BL18:SE:NANODAC1:CH2:PV',
#  'BL18:SE:NANODAC1:VCH3:PV',
#  'BL18:SE:ND1:CH1:PV',
#  'BL18:SE:ND1:CH2:PV',
#  'BL18:SE:ND1:VCH3:PV',
#  'CryoSampleSpacePress',
#  'CryoSampleTemp',
#  'CryoTempSP1',
#  'CryoTempSP2',
#  'CryoVTIPress',
#  'CryoVTITemp',
#  'DilfridgeReading1',
#  'DilfridgeReading10',
#  'DilfridgeReading11',
#  'DilfridgeReading12',
#  'DilfridgeReading13',
#  'DilfridgeReading14',
#  'DilfridgeReading15',
#  'DilfridgeReading2',
#  'DilfridgeReading3',
#  'DilfridgeReading4',
#  'DilfridgeReading5',
#  'DilfridgeReading6',
#  'DilfridgeReading7',
#  'DilfridgeReading8',
#  'DilfridgeReading9',
#  'EnergyRequest',
#  'GaussMeterField',
#  'LKS1A',
#  'LKS1B',
#  'LKS1C',
#  'LKS1D',
#  'LKS2A',
#  'LKS2B',
#  'LKS2C',
#  'LKS2D',
#  'LambdaRequest',
#  'MKS6601',
#  'MKS6602',
#  'MKS6603',
#  'MKS6604',
#  'ND1CH1',
#  'ND1CH2',
#  'ND1VCH3',
#  'Nanodac1CH1',
#  'Nanodac1CH2',
#  'Nanodac1VCH3',
#  'Phase1',
#  'Phase2',
#  'Phase3',
#  'PhaseLocked1',
#  'PhaseLocked2',
#  'PhaseRequest1',
#  'PhaseRequest2',
#  'PhaseRequest3',
#  'S1HCenter',
#  'S1HWidth',
#  'S1VCenter',
#  'S1VHeight',
#  'S2HCenter',
#  'S2HWidth',
#  'S2VCenter',
#  'S2VHeight',
#  'Sample:Axis1',
#  'Sample:Axis1.DESC',
#  'Sample:Axis1.RBV',
#  'SampleComments',
#  'SampleContainer',
#  'SampleDensity',
#  'SampleDescription',
#  'SampleFormula',
#  'SampleId',
#  'SampleMass',
#  'SampleName',
#  'SampleNature',
#  'Speed1',
#  'Speed2',
#  'Speed3',
#  'SpeedRequest1',
#  'SpeedRequest2',
#  'SpeedRequest3',
#  'attenuator1',
#  'attenuator1Request',
#  'attenuator2',
#  'attenuator2Request',
#  'chtrans',
#  'chtransRequest',
#  'collimator',
#  'collimatorlift',
#  'frequency',
#  'pause',
#  'proton_charge',
#  's1b',
#  's1bRequest',
#  's1l',
#  's1lRequest',
#  's1r',
#  's1rRequest',
#  's1t',
#  's1tRequest',
#  's2b',
#  's2bRequest',
#  's2l',
#  's2lRequest',
#  's2r',
#  's2rRequest',
#  's2t',
#  's2tRequest',
#  'scan_index',
#  'vAttenuator1',
#  'vAttenuator2',
#  'vChTrans',
#  'vCollState',
#  'start_time',
#  'end_time',
#  'gd_prtn_chrg',
#  'run_start',
#  'run_title',
#  'file_notes',
#  'run_number',
#  'experiment_identifier',
#  'duration',
#  'Filename',
#  'deltaE-mode']
